# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

from bs4 import BeautifulSoup

raw = requests.get("https://urlhaus.abuse.ch/downloads/csv_recent/")

html = BeautifulSoup(raw.text, 'html.parser')
print(html)
# Out:
# ################################################################
# # abuse.ch URLhaus Database Dump (CSV - recent URLs only)      #
# # Last updated: 2020-04-09 18:30:25 (UTC)                      #
# #                                                              #
# # Terms Of Use: https://urlhaus.abuse.ch/api/                  #
# # For questions please contact urlhaus [at] abuse.ch           #
# ################################################################
# #
# # id,dateadded,url,url_status,threat,tags,urlhaus_link,reporter
# "337541","2020-04-09 18:30:25","https://cdn.discordapp.com/attachments/694213456525656106/697687189794062457/Order_Confirmation.doc","online","malware_download","None","https://urlhaus.abuse.ch/url/337541/","JayTHL"
# "337540","2020-04-09 18:30:10","https://cdn.discordapp.com/attachments/696863000895815833/697683988856438845/ori2.0.pif","online","malware_download","AgentTesla","https://urlhaus.abuse.ch/url/337540/","JayTHL"
# ...

# %%
clear

# %%
df=df.head(18)

# %%
# Out:
#   name  age
# 2    C   25
# 3    D   22
# 4    E   20

# %%
pip

# %%
import pandas as pd

# %%
df = pd.read_csv('data/friend.csv')
df[0:2]
# Out:
#   name  age
# 0    A   21
# 1    B   22

# %%
df.loc[[0,2]]
# Out:
#   name  age
# 0    A   21
# 2    C   25

# %%
df_filtered = df[df.age >22]

# %%
df_filtered
# Out:
#   name  age
# 2    C   25

# %%
from collections import OrderedDict
import pandas as pd

# %%
df
# Out:
#   name  age
# 0    A   21
# 1    B   22
# 2    C   25
# 3    D   22
# 4    E   20

# %%
df[ (df.name =='A') & (df.age >20)]
# Out:
#   name  age
# 0    A   21

# %%
friend_list =[
    ['John','20','student'],
    ['John1','22','student'],
    ['John2','24','student']
]
df = pd.DataFrame.from_records(friend_list)
df
# Out:
#        0   1        2
# 0   John  20  student
# 1  John1  22  student
# 2  John2  24  student

# %%
df = pd.read_csv('data/ddds.txt')
df=df.iloc[:,2:4]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-25c27bdd19a7> in <module>
# ----> 1 df = pd.read_csv('data/ddds.txt')
#       2 df=df.iloc[:,2:4]
#       3 df
#
# NameError: name 'pd' is not defined

# %%
 df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
 df2 = pd.read_csv('data/payload.txt', comment="#", header = None, names=['firstseen','url','filetype','md5','sha256','signature'])

# %%
df2
# Out:
#                    firstseen  \
# 0        2020-04-10 05:00:28
# 1        2020-04-10 05:00:26
# 2        2020-04-10 04:17:05
# 3        2020-04-10 04:17:03
# 4        2020-04-10 04:16:41
# ...                      ...
# 1363945  2018-03-05 15:44:57
# 1363946  2018-03-05 15:22:10
# 1363947  2018-03-05 15:13:51
# 1363948  2018-03-05 14:21:09
# 1363949  2018-03-05 14:18:19
#
#                                                        url filetype  \
# 0                http://sinacloud.net/yun2016/Bwin732d.rar      exe
# 1               http://sinacloud.net/yun2016/PrsProt32.rar      exe
# 2        http://bienkich.edu.vn/slider/7042158/7042158.zip      zip
# 3        https://ceirecrear.com.br/wp-content/plugins/a...      exe
# 4             http://www.reyvencontracting.com/ray/pom.php      exe
# ...                                                    ...      ...
# 1363945  http://beautyevent.ru/Invoice-for-j/b-03/05/2018/      doc
# ...

# %%
df3=df2.iloc[:,1]

# %%
df3
# Out:
# 0                  http://sinacloud.net/yun2016/Bwin732d.rar
# 1                 http://sinacloud.net/yun2016/PrsProt32.rar
# 2          http://bienkich.edu.vn/slider/7042158/7042158.zip
# 3          https://ceirecrear.com.br/wp-content/plugins/a...
# 4               http://www.reyvencontracting.com/ray/pom.php
#                                  ...
# 1363945    http://beautyevent.ru/Invoice-for-j/b-03/05/2018/
# 1363946                     http://www.davidephoto.it/GsnIO/
# 1363947                     http://www.davidephoto.it/GsnIO/
# 1363948                        https://girlhistory.ru/dUZfW/
# 1363949    http://beautyevent.ru/Invoice-for-j/b-03/05/2018/
# Name: url, Length: 1363950, dtype: object

# %%
find=input("URL 입력 >>")

# %%
urlcount=0
for f in df3:
    if find == f:
        urlcount +=1
if urlcount > 0:
    print("악성 url 기록 발견")
